# %%
pip install mysql-connector-python faker
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\ifc-60\anaconda3\lib\site-packages (9.2.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: faker in c:\users\ifc-60\anaconda3\lib\site-packages (36.1.1)
# Requirement already satisfied: tzdata in c:\users\ifc-60\anaconda3\lib\site-packages (from faker) (2023.3)

# %%
import mysql.connector
import random
from faker import Faker
from datetime import datetime,timedelta

# %%
fake = Faker()

# %%
# Creating a connection to the database
DB_CONFIG = {
    "host": "localhost",
    "user":"root",
    "password":"root",
    "database":"crop_management"
}

# %%
# Connect to MySQL
conn = mysql.connector.connect(**DB_CONFIG)
cursor = conn.cursor()

# %%
# Create crops table if not exists
cursor.execute("""
CREATE TABLE IF NOT EXISTS crops (
    id INT AUTO_INCREMENT PRIMARY KEY,
    crop_name VARCHAR(255) NOT NULL,
    planting_date DATE,
    harvest_date DATE,
    growth_stage VARCHAR(255),
    pest_control_measures TEXT,
    yield_prediction INT
)
""")
conn.commit()

# %%
# List of sample crop names
crop_names = ["Wheat", "Rice", "Corn", "Soybean", "Barley", "Sugarcane", "Cotton", "Potato", "Tomato", "Lettuce"]

# List of possible growth stages
growth_stages = ["Seedling", "Vegetative", "Flowering", "Fruiting", "Maturity"]

# List of sample pest control measures
pest_control_measures_list = [
    "Use of organic pesticides",
    "Crop rotation",
    "Neem oil application",
    "Biological pest control",
    "Chemical pesticides",
    "Regular field monitoring",
]

# %%
# Function to generate random data for crops
def generate_data():
    crop_name = random.choice(crop_names)
    planting_date = fake.date_between(start_date="-2y", end_date="today")  # Planting in last 2 years
    harvest_date = planting_date + timedelta(days=random.randint(60, 180))  # Harvest after 2-6 months
    growth_stage = random.choice(growth_stages)
    pest_control = random.choice(pest_control_measures_list)
    yield_prediction = random.randint(500, 5000)  # Yield in kg
    
    return (crop_name, planting_date, harvest_date, growth_stage, pest_control, yield_prediction)

# %%
# Batch insert records in chunks
batch_size = 100000  # Insert 10,000 at a time for efficiency
total_records = 20000000

for i in range(0, total_records, batch_size):
    data_batch = [generate_data() for _ in range(batch_size)]
    
    # Execute batch insert
    cursor.executemany("""
        INSERT INTO crops (crop_name, planting_date, harvest_date, growth_stage, pest_control_measures, yield_prediction)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, data_batch)
    conn.commit()
    
    print(f"{i + batch_size} records inserted...")

print("✅ Data insertion completed successfully!")

# Close the database connection
cursor.close()
conn.close()
# Out:
# 100000 records inserted...
# 200000 records inserted...
# 300000 records inserted...
# 400000 records inserted...
# 500000 records inserted...
# 600000 records inserted...
# 700000 records inserted...
# 800000 records inserted...
# 900000 records inserted...
# 1000000 records inserted...
# 1100000 records inserted...
# 1200000 records inserted...
# 1300000 records inserted...
# 1400000 records inserted...
# 1500000 records inserted...
# 1600000 records inserted...
# 1700000 records inserted...
# 1800000 records inserted...
# 1900000 records inserted...
# 2000000 records inserted...
# 2100000 records inserted...
# 2200000 records inserted...
# 2300000 records inserted...
# 2400000 records inserted...
# 2500000 records inserted...
# 2600000 records inserted...
# 2700000 records inserted...
# 2800000 records inserted...
# 2900000 records inserted...
# 3000000 records inserted...
# 3100000 records inserted...
# 3200000 records inserted...
# 3300000 records inserted...
# 3400000 records inserted...
# 3500000 records inserted...
# 3600000 records inserted...
# 3700000 records inserted...
# 3800000 records inserted...
# 3900000 records inserted...
# 4000000 records inserted...
# 4100000 records inserted...
# 4200000 records inserted...
# 4300000 records inserted...
# 4400000 records inserted...
# 4500000 records inserted...
# 4600000 records inserted...
# 4700000 records inserted...
# 4800000 records inserted...
# 4900000 records inserted...
# 5000000 records inserted...
# 5100000 records inserted...
# 5200000 records inserted...
# 5300000 records inserted...
# 5400000 records inserted...
# 5500000 records inserted...
# 5600000 records inserted...
# 5700000 records inserted...
# 5800000 records inserted...
# 5900000 records inserted...
# 6000000 records inserted...
# 6100000 records inserted...
# 6200000 records inserted...
# 6300000 records inserted...
# 6400000 records inserted...
# 6500000 records inserted...
# 6600000 records inserted...
# 6700000 records inserted...
# 6800000 records inserted...
# 6900000 records inserted...
# 7000000 records inserted...
# 7100000 records inserted...
# 7200000 records inserted...
# 7300000 records inserted...
# 7400000 records inserted...
# 7500000 records inserted...
# 7600000 records inserted...
# 7700000 records inserted...
# 7800000 records inserted...
# 7900000 records inserted...
# 8000000 records inserted...
# 8100000 records inserted...
# 8200000 records inserted...
# 8300000 records inserted...
# 8400000 records inserted...
# 8500000 records inserted...
# 8600000 records inserted...
# 8700000 records inserted...
# 8800000 records inserted...
# 8900000 records inserted...
# 9000000 records inserted...
# 9100000 records inserted...
# 9200000 records inserted...
# 9300000 records inserted...
# 9400000 records inserted...
# 9500000 records inserted...
# 9600000 records inserted...
# 9700000 records inserted...
# 9800000 records inserted...
# 9900000 records inserted...
# 10000000 records inserted...
# 10100000 records inserted...
# 10200000 records inserted...
# 10300000 records inserted...
# 10400000 records inserted...
# 10500000 records inserted...
# 10600000 records inserted...
# 10700000 records inserted...
# 10800000 records inserted...
# 10900000 records inserted...
# 11000000 records inserted...
# 11100000 records inserted...
# 11200000 records inserted...
# 11300000 records inserted...
# 11400000 records inserted...
# 11500000 records inserted...
# 11600000 records inserted...
# 11700000 records inserted...
# 11800000 records inserted...
# 11900000 records inserted...
# 12000000 records inserted...
# 12100000 records inserted...
# 12200000 records inserted...
# 12300000 records inserted...
# 12400000 records inserted...
# 12500000 records inserted...
# 12600000 records inserted...
# 12700000 records inserted...
# 12800000 records inserted...
# 12900000 records inserted...
# 13000000 records inserted...
# 13100000 records inserted...
# 13200000 records inserted...
# 13300000 records inserted...
# 13400000 records inserted...
# 13500000 records inserted...
# 13600000 records inserted...
# 13700000 records inserted...
# 13800000 records inserted...
# 13900000 records inserted...
# 14000000 records inserted...
# 14100000 records inserted...
# 14200000 records inserted...
# 14300000 records inserted...
# 14400000 records inserted...
# 14500000 records inserted...
# 14600000 records inserted...
# 14700000 records inserted...
# 14800000 records inserted...
# 14900000 records inserted...
# 15000000 records inserted...
# 15100000 records inserted...
# 15200000 records inserted...
# 15300000 records inserted...
# 15400000 records inserted...
# 15500000 records inserted...
# 15600000 records inserted...
# 15700000 records inserted...
# 15800000 records inserted...
# 15900000 records inserted...
# 16000000 records inserted...
# 16100000 records inserted...
# 16200000 records inserted...
# 16300000 records inserted...
# 16400000 records inserted...
# 16500000 records inserted...
# 16600000 records inserted...
# 16700000 records inserted...
# 16800000 records inserted...
# 16900000 records inserted...
# 17000000 records inserted...
# 17100000 records inserted...
# 17200000 records inserted...
# 17300000 records inserted...
# 17400000 records inserted...
# 17500000 records inserted...
# 17600000 records inserted...
# 17700000 records inserted...
# 17800000 records inserted...
# 17900000 records inserted...
# 18000000 records inserted...
# 18100000 records inserted...
# 18200000 records inserted...
# 18300000 records inserted...
# 18400000 records inserted...
# 18500000 records inserted...
# 18600000 records inserted...
# 18700000 records inserted...
# 18800000 records inserted...
# 18900000 records inserted...
# 19000000 records inserted...
# 19100000 records inserted...
# 19200000 records inserted...
# 19300000 records inserted...
# 19400000 records inserted...
# 19500000 records inserted...
# 19600000 records inserted...
# 19700000 records inserted...
# 19800000 records inserted...
# 19900000 records inserted...
# 20000000 records inserted...
# ✅ Data insertion completed successfully!

# %%
import pandas as pd

# %%
def fetch_table_data(table_name):
    # The connect() constructor creates a connection to the MySQL server and returns a MySQLConnection object.
    cnx = mysql.connector.connect(
        host='localhost',
        database='crop_management',
        user='root',
        password='root'
    )

    cursor = cnx.cursor()
    cursor.execute('select * from ' + table_name)

    header = [row[0] for row in cursor.description]

    rows = cursor.fetchall()

    # Closing connection
    cnx.close()

    return header, rows
def export(table_name):
    header, rows = fetch_table_data(table_name)

    # Create csv file
    f = open(table_name + '.csv', 'w')

    # Write header
    f.write(','.join(header) + '\n')

    for row in rows:
        f.write(','.join(str(r) for r in row) + '\n')

    f.close()
    print(str(len(rows)) + ' rows written successfully to ' + f.name)


# Tables to be exported
export('crops')
# Out:
# 20000000 rows written successfully to crops.csv

# %%
import pandas as pd
df = pd.read_csv("crops.csv")

# %%
df
# Out:
#                 id  crop_name planting_date harvest_date growth_stage  \
# 0                1  Sugarcane    2023-06-06   2023-11-04    Flowering
# 1                2     Barley    2023-10-09   2024-03-14     Fruiting
# 2                3     Cotton    2024-12-08   2025-05-29   Vegetative
# 3                4     Potato    2024-01-19   2024-05-15    Flowering
# 4                5  Sugarcane    2023-07-11   2023-10-30     Maturity
# ...            ...        ...           ...          ...          ...
# 19999995  19999996    Soybean    2024-05-26   2024-07-31     Fruiting
# 19999996  19999997     Cotton    2023-09-22   2023-12-12   Vegetative
# 19999997  19999998      Wheat    2024-12-25   2025-06-12    Flowering
# 19999998  19999999    Lettuce    2024-03-15   2024-08-02     Fruiting
# 19999999  20000000       Corn    2023-11-07   2024-01-12   Vegetative
#
#               pest_control_measures  yield_prediction
# 0                     Crop rotation              3180
# 1                     Crop rotation              3435
# 2              Neem oil application              4289
# 3                     Crop rotation              3495
# 4              Neem oil application              4342
# ...                             ...               ...
# 19999995        Chemical pesticides              3742
# 19999996  Use of organic pesticides              3618
# 19999997        Chemical pesticides              2559
# 19999998              Crop rotation              3668
# 19999999        Chemical pesticides              1515
#
# [20000000 rows x 7 columns]

# %%
df.size
# Out:
# 140000000

# %%
import os

file_path = "crops.csv"  # Replace with your actual file path
file_size = os.path.getsize(file_path)  # Size in bytes

print(f"File size: {file_size / (1024 * 1024):.2f} MB")  # Convert to MB
# Out:
# File size: 1422.88 MB
